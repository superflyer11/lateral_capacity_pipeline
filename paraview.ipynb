# %%
vtk_filepath = r"/mofem_install/jupyter/thomas/mfront_example_test/simulations/day_0_sim_12_2024_08_17_12_31_23/day_0_sim_12_2024_08_17_12_31_23.vtk"
csv_filepath = r"/mofem_install/jupyter/thomas/mfront_example_test/simulations/day_0_sim_12_2024_08_17_12_31_23/day_0_sim_12_2024_08_17_12_31_23.csv"

# !/mofem_install/jupyter/thomas/ParaView-5.13.0-RC1-MPI-Linux-Python3.10-x86_64/bin/pvpython /mofem_install/jupyter/thomas/mfront_example_test/src/paraview_test.py {vtk_filepath} {csv_filepath}
# Out:
# Success

# %%
# trace generated using paraview version 5.12.0
#import paraview
#paraview.compatibility.major = 5
#paraview.compatibility.minor = 12

#### import the simple module from the paraview
from paraview.simple import *
#### disable automatic camera reset on 'Show'
paraview.simple._DisableFirstRenderCameraReset()

# get active source.
fx_18000000_fy_0_fz_0_2024_08_16_16_20_44vtk = GetActiveSource()

# set active source
SetActiveSource(fx_18000000_fy_0_fz_0_2024_08_16_16_20_44vtk)

# create a new 'Plot Over Line'
plotOverLine2 = PlotOverLine(registrationName='PlotOverLine2', Input=fx_18000000_fy_0_fz_0_2024_08_16_16_20_44vtk)

# find source
plotOverLine1 = FindSource('PlotOverLine1')

# Properties modified on plotOverLine2
plotOverLine2.Point1 = [1.0, 0.0, 0.0]
plotOverLine2.Point2 = [1.0, 0.0, -40.0]

# get active view
renderView1 = GetActiveViewOrCreate('RenderView')

# show data in view
plotOverLine2Display = Show(plotOverLine2, renderView1, 'GeometryRepresentation')

# trace defaults for the display properties.
plotOverLine2Display.Representation = 'Surface'

# Create a new 'Line Chart View'
lineChartView2 = CreateView('XYChartView')

# show data in view
plotOverLine2Display_1 = Show(plotOverLine2, lineChartView2, 'XYChartRepresentation')

# get layout
layout1 = GetLayoutByName("Layout #1")

# add view to a layout so it's visible in UI
AssignViewToLayout(view=lineChartView2, layout=layout1, hint=1)

# Properties modified on plotOverLine2Display_1
plotOverLine2Display_1.SeriesOpacity = ['arc_length', '1', 'DISPLACEMENT_X', '1', 'DISPLACEMENT_Y', '1', 'DISPLACEMENT_Z', '1', 'DISPLACEMENT_Magnitude', '1', 'GLOBAL_ID', '1', 'NB_IN_THE_LOOP', '1', 'PARALLEL_PARTITION', '1', 'STRAIN_0', '1', 'STRAIN_1', '1', 'STRAIN_2', '1', 'STRAIN_3', '1', 'STRAIN_4', '1', 'STRAIN_5', '1', 'STRAIN_6', '1', 'STRAIN_7', '1', 'STRAIN_8', '1', 'STRAIN_Magnitude', '1', 'STRESS_0', '1', 'STRESS_1', '1', 'STRESS_2', '1', 'STRESS_3', '1', 'STRESS_4', '1', 'STRESS_5', '1', 'STRESS_6', '1', 'STRESS_7', '1', 'STRESS_8', '1', 'STRESS_Magnitude', '1', 'vtkValidPointMask', '1', 'Points_X', '1', 'Points_Y', '1', 'Points_Z', '1', 'Points_Magnitude', '1']
plotOverLine2Display_1.SeriesPlotCorner = ['DISPLACEMENT_Magnitude', '0', 'DISPLACEMENT_X', '0', 'DISPLACEMENT_Y', '0', 'DISPLACEMENT_Z', '0', 'GLOBAL_ID', '0', 'NB_IN_THE_LOOP', '0', 'PARALLEL_PARTITION', '0', 'Points_Magnitude', '0', 'Points_X', '0', 'Points_Y', '0', 'Points_Z', '0', 'STRAIN_0', '0', 'STRAIN_1', '0', 'STRAIN_2', '0', 'STRAIN_3', '0', 'STRAIN_4', '0', 'STRAIN_5', '0', 'STRAIN_6', '0', 'STRAIN_7', '0', 'STRAIN_8', '0', 'STRAIN_Magnitude', '0', 'STRESS_0', '0', 'STRESS_1', '0', 'STRESS_2', '0', 'STRESS_3', '0', 'STRESS_4', '0', 'STRESS_5', '0', 'STRESS_6', '0', 'STRESS_7', '0', 'STRESS_8', '0', 'STRESS_Magnitude', '0', 'arc_length', '0', 'vtkValidPointMask', '0']
plotOverLine2Display_1.SeriesLineStyle = ['DISPLACEMENT_Magnitude', '1', 'DISPLACEMENT_X', '1', 'DISPLACEMENT_Y', '1', 'DISPLACEMENT_Z', '1', 'GLOBAL_ID', '1', 'NB_IN_THE_LOOP', '1', 'PARALLEL_PARTITION', '1', 'Points_Magnitude', '1', 'Points_X', '1', 'Points_Y', '1', 'Points_Z', '1', 'STRAIN_0', '1', 'STRAIN_1', '1', 'STRAIN_2', '1', 'STRAIN_3', '1', 'STRAIN_4', '1', 'STRAIN_5', '1', 'STRAIN_6', '1', 'STRAIN_7', '1', 'STRAIN_8', '1', 'STRAIN_Magnitude', '1', 'STRESS_0', '1', 'STRESS_1', '1', 'STRESS_2', '1', 'STRESS_3', '1', 'STRESS_4', '1', 'STRESS_5', '1', 'STRESS_6', '1', 'STRESS_7', '1', 'STRESS_8', '1', 'STRESS_Magnitude', '1', 'arc_length', '1', 'vtkValidPointMask', '1']
plotOverLine2Display_1.SeriesLineThickness = ['DISPLACEMENT_Magnitude', '2', 'DISPLACEMENT_X', '2', 'DISPLACEMENT_Y', '2', 'DISPLACEMENT_Z', '2', 'GLOBAL_ID', '2', 'NB_IN_THE_LOOP', '2', 'PARALLEL_PARTITION', '2', 'Points_Magnitude', '2', 'Points_X', '2', 'Points_Y', '2', 'Points_Z', '2', 'STRAIN_0', '2', 'STRAIN_1', '2', 'STRAIN_2', '2', 'STRAIN_3', '2', 'STRAIN_4', '2', 'STRAIN_5', '2', 'STRAIN_6', '2', 'STRAIN_7', '2', 'STRAIN_8', '2', 'STRAIN_Magnitude', '2', 'STRESS_0', '2', 'STRESS_1', '2', 'STRESS_2', '2', 'STRESS_3', '2', 'STRESS_4', '2', 'STRESS_5', '2', 'STRESS_6', '2', 'STRESS_7', '2', 'STRESS_8', '2', 'STRESS_Magnitude', '2', 'arc_length', '2', 'vtkValidPointMask', '2']
plotOverLine2Display_1.SeriesMarkerStyle = ['DISPLACEMENT_Magnitude', '0', 'DISPLACEMENT_X', '0', 'DISPLACEMENT_Y', '0', 'DISPLACEMENT_Z', '0', 'GLOBAL_ID', '0', 'NB_IN_THE_LOOP', '0', 'PARALLEL_PARTITION', '0', 'Points_Magnitude', '0', 'Points_X', '0', 'Points_Y', '0', 'Points_Z', '0', 'STRAIN_0', '0', 'STRAIN_1', '0', 'STRAIN_2', '0', 'STRAIN_3', '0', 'STRAIN_4', '0', 'STRAIN_5', '0', 'STRAIN_6', '0', 'STRAIN_7', '0', 'STRAIN_8', '0', 'STRAIN_Magnitude', '0', 'STRESS_0', '0', 'STRESS_1', '0', 'STRESS_2', '0', 'STRESS_3', '0', 'STRESS_4', '0', 'STRESS_5', '0', 'STRESS_6', '0', 'STRESS_7', '0', 'STRESS_8', '0', 'STRESS_Magnitude', '0', 'arc_length', '0', 'vtkValidPointMask', '0']
plotOverLine2Display_1.SeriesMarkerSize = ['DISPLACEMENT_Magnitude', '4', 'DISPLACEMENT_X', '4', 'DISPLACEMENT_Y', '4', 'DISPLACEMENT_Z', '4', 'GLOBAL_ID', '4', 'NB_IN_THE_LOOP', '4', 'PARALLEL_PARTITION', '4', 'Points_Magnitude', '4', 'Points_X', '4', 'Points_Y', '4', 'Points_Z', '4', 'STRAIN_0', '4', 'STRAIN_1', '4', 'STRAIN_2', '4', 'STRAIN_3', '4', 'STRAIN_4', '4', 'STRAIN_5', '4', 'STRAIN_6', '4', 'STRAIN_7', '4', 'STRAIN_8', '4', 'STRAIN_Magnitude', '4', 'STRESS_0', '4', 'STRESS_1', '4', 'STRESS_2', '4', 'STRESS_3', '4', 'STRESS_4', '4', 'STRESS_5', '4', 'STRESS_6', '4', 'STRESS_7', '4', 'STRESS_8', '4', 'STRESS_Magnitude', '4', 'arc_length', '4', 'vtkValidPointMask', '4']

# update the view to ensure updated data information
renderView1.Update()

# find view
lineChartView1 = FindViewOrCreate('LineChartView1', viewtype='XYChartView')

# set active view
SetActiveView(lineChartView1)

# destroy lineChartView1
Delete(lineChartView1)
del lineChartView1

# close an empty frame
layout1.Collapse(2)

# set active view
SetActiveView(lineChartView2)

# Properties modified on plotOverLine2Display_1
plotOverLine2Display_1.XArrayName = 'Points_X'

# Properties modified on plotOverLine2Display_1
plotOverLine2Display_1.XArrayName = 'DISPLACEMENT_X'

# Properties modified on plotOverLine2Display_1
plotOverLine2Display_1.XArrayName = 'DISPLACEMENT_Magnitude'

# Properties modified on plotOverLine2Display_1
plotOverLine2Display_1.SeriesVisibility = ['arc_length', 'DISPLACEMENT_Magnitude', 'DISPLACEMENT_X', 'DISPLACEMENT_Y', 'DISPLACEMENT_Z', 'GLOBAL_ID', 'NB_IN_THE_LOOP', 'PARALLEL_PARTITION', 'Points_Magnitude', 'Points_X', 'Points_Y', 'Points_Z', 'STRAIN_0', 'STRAIN_1', 'STRAIN_2', 'STRAIN_3', 'STRAIN_4', 'STRAIN_5', 'STRAIN_6', 'STRAIN_7', 'STRAIN_8', 'STRAIN_Magnitude', 'STRESS_0', 'STRESS_1', 'STRESS_2', 'STRESS_3', 'STRESS_4', 'STRESS_5', 'STRESS_6', 'STRESS_7', 'STRESS_8', 'STRESS_Magnitude', 'vtkValidPointMask']

# Properties modified on plotOverLine2Display_1
plotOverLine2Display_1.SeriesVisibility = []

# Properties modified on plotOverLine2Display_1
plotOverLine2Display_1.SeriesVisibility = ['Points_Z']

# save data
SaveData('C:\\Users\\laito\\Downloads\\dis_to_depth.csv', proxy=plotOverLine2, PointDataArrays=['DISPLACEMENT', 'GLOBAL_ID', 'NB_IN_THE_LOOP', 'PARALLEL_PARTITION', 'STRAIN', 'STRESS', 'arc_length', 'vtkValidPointMask'])

#================================================================
# addendum: following script captures some of the application
# state to faithfully reproduce the visualization during playback
#================================================================

#--------------------------------
# saving layout sizes for layouts

# layout/tab size in pixels
layout1.SetSize(971, 733)

#-----------------------------------
# saving camera placements for views

# current camera placement for renderView1
renderView1.CameraPosition = [-21.018335856015845, 134.8964597858672, 1.2708186106396386]
renderView1.CameraFocalPoint = [-4.167439942453641e-15, -40.00000000000001, -15.000000000000002]
renderView1.CameraViewUp = [0.11108826832573077, -0.07881400996406028, 0.9906804472047359]
renderView1.CameraParallelScale = 98.5149646197041


##--------------------------------------------
## You may need to add some code at the end of this python script depending on your usage, eg:
#
## Render all views to see them appears
# RenderAllViews()
#
## Interact with the view, usefull when running from pvpython
# Interact()
#
## Save a screenshot of the active view
# SaveScreenshot("path/to/screenshot.png")
#
## Save a screenshot of a layout (multiple splitted view)
# SaveScreenshot("path/to/screenshot.png", GetLayout())
#
## Save all "Extractors" from the pipeline browser
# SaveExtracts()
#
## Save a animation of the current active view
# SaveAnimation()
#
## Please refer to the documentation of paraview.simple
## https://kitware.github.io/paraview-docs/latest/python/paraview.simple.html
##--------------------------------------------
